# %% [markdown]
# ## Coursera Capstone Project

# %% [markdown]
# This Notebook is intendened to complete the capstone project on Coursera course

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
